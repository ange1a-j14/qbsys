# %%
from sympy import *
from sympy.abc import x
from sympy.printing.latex import LatexPrinter, print_latex

# %%
t, chi_r, chi_i, Delta, epsilon = symbols('t chi_r chi_i Delta epsilon')
psi1, psi2 = symbols('psi_1, psi_2', cls=Function)
phi1, phi2 = symbols('phi_1, phi_2', cls=Function)

# %%
eq1 = Eq(Derivative(psi1(t),t), epsilon/2*psi2(t) + Delta/2*phi2(t))
eq2 = Eq(Derivative(psi2(t),t), -epsilon/2*psi1(t) - Delta/2*phi1(t))
eq3 = Eq(Derivative(phi1(t),t), -epsilon/2*phi2(t) + Delta/2*psi2(t) + chi_r*psi2(t) + chi_i*psi1(t))
eq4 = Eq(Derivative(phi2(t),t), epsilon/2*phi1(t) - Delta/2*psi1(t) - chi_r*psi1(t) + chi_i*psi2(t))

eq = (eq1, eq2, eq3, eq4)
for equation in eq:
    pretty_print(equation)
# Out:
# d           Δ⋅φ₂(t)   ε⋅ψ₂(t)
# ──(ψ₁(t)) = ─────── + ───────
# dt             2         2
# d             Δ⋅φ₁(t)   ε⋅ψ₁(t)
# ──(ψ₂(t)) = - ─────── - ───────
# dt               2         2
# d           Δ⋅ψ₂(t)                         ε⋅φ₂(t)
# ──(φ₁(t)) = ─────── + χᵢ⋅ψ₁(t) + χᵣ⋅ψ₂(t) - ───────
# dt             2                               2
# d             Δ⋅ψ₁(t)                         ε⋅φ₁(t)
# ──(φ₂(t)) = - ─────── + χᵢ⋅ψ₂(t) - χᵣ⋅ψ₁(t) + ───────
# dt               2                               2

# %%
answer = dsolve(eq)

# %%
answer[3]
# Out:
# Eq(phi_2(t), C1*exp(-t*((-2*re(Delta)*im(Delta) - 2*re(epsilon)*im(epsilon) - 2*re(Delta*chi_i) - 2*im(Delta*chi_r))**2 + (-re(Delta)**2 - re(epsilon)**2 - 2*re(Delta*chi_r) + im(Delta)**2 + im(epsilon)**2 + 2*im(Delta*chi_i))**2)**(1/4)*cos(atan2(-2*re(Delta)*im(Delta) - 2*re(epsilon)*im(epsilon) - 2*re(Delta*chi_i) - 2*im(Delta*chi_r), -re(Delta)**2 - re(epsilon)**2 - 2*re(Delta*chi_r) + im(Delta)**2 + im(epsilon)**2 + 2*im(Delta*chi_i))/2)/2)*cos(t*((-2*re(Delta)*im(Delta) - 2*re(epsilon)*im(epsilon) - 2*re(Delta*chi_i) - 2*im(Delta*chi_r))**2 + (-re(Delta)**2 - re(epsilon)**2 - 2*re(Delta*chi_r) + im(Delta)**2 + im(epsilon)**2 + 2*im(Delta*chi_i))**2)**(1/4)*sin(atan2(-2*re(Delta)*im(Delta) - 2*re(epsilon)*im(epsilon) - 2*re(Delta*chi_i) - 2*im(Delta*chi_r), -re(Delta)**2 - re(epsilon)**2 - 2*re(Delta*chi_r) + im(Delta)**2 + im(epsilon)**2 + 2*im(Delta*chi_i))/2)/2) + C2*exp(-t*((-2*re(Delta)*im(Delta) - 2*re(epsilon)*im(epsilon) - 2*re(Delta*chi_i) - 2*im(Delta*chi_r))**2 + (-re
# ...
